# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns


import os
for dirname, _, filenames in os.walk('/Users/raunaq/Desktop/Sales'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Users/raunaq/Desktop/Sales/Advertising.csv
# /Users/raunaq/Desktop/Sales/.DS_Store
# /Users/raunaq/Desktop/Sales/sales-prediction-model.ipynb
# /Users/raunaq/Desktop/Sales/sales-prediction-using-python.ipynb

# %% [markdown]
# <img src= "https://media.istockphoto.com/id/643956812/photo/sales-imporvement.jpg?s=612x612&w=0&k=20&c=BERc0TihWU4sZpzSTBsJpQ6em2wowpYCtHA0Iwbl7QM=" alt ="sales" style='width: 700px;'>

# %% [markdown]
# # Table of Content
# * Import dataset
# * Cleaning
# * Transforming
# * Train test split
# * Scaling
# * Model training
# * Accuracy

# %%
df=pd.read_csv('/Users/raunaq/Desktop/Sales/Advertising.csv')

# %% [markdown]
# # Import dataset

# %%
df.head(10)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# # Cleaning

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   10.6

# %% [markdown]
# # Transforming

# %%
df['TV']=df['TV'].astype('int')

# %%
df['Radio']=df['Radio'].astype('int')

# %%
df['Newspaper']=df['Newspaper'].astype('int')

# %%
df['Sales']=df['Sales'].astype('int')

# %%
df.head(10)
# Out:
#     TV  Radio  Newspaper  Sales
# 0  230     37         69     22
# 1   44     39         45     10
# 2   17     45         69      9
# 3  151     41         58     18
# 4  180     10         58     12
# 5    8     48         75      7
# 6   57     32         23     11
# 7  120     19         11     13
# 8    8      2          1      4
# 9  199      2         21     10

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # EDA

# %%
sns.lineplot(df['TV'])
# Out:
# <AxesSubplot:ylabel='TV'>

# %%
sns.scatterplot(df['Radio'])
# Out:
# <AxesSubplot:ylabel='Radio'>

# %%
sns.stripplot(df['TV'])
# Out:
# <AxesSubplot:ylabel='TV'>

# %%
sns.scatterplot(df['Radio'])
# Out:
# <AxesSubplot:ylabel='Radio'>

# %%
sns.scatterplot(df['Sales'])
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
x=df.iloc[:,0:-1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # train test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
Sc=StandardScaler()

# %% [markdown]
# # scaling

# %%
x_train_scaled=Sc.fit_transform(x_train)

# %%
x_test_scaled=Sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %% [markdown]
# # model training

# %%
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8811836354878555

# %% [markdown]
# # got 88.12 % accuracy
